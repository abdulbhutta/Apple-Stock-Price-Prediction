# %%
# !pip install yfinance
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: yfinance in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (0.2.4)
# Requirement already satisfied: html5lib>=1.1 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: lxml>=4.9.1 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: pandas>=1.3.0 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: requests>=2.26 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.20.3)
# Requirement already satisfied: cryptography>=3.3.2 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (3.4.8)
# Requirement already satisfied: soupsieve>1.2 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.2.1)
# Requirement already satisfied: cffi>=1.12 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=3.3.2->yfinance) (1.14.6)
# Requirement already satisfied: pycparser in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.20)
# Requirement already satisfied: webencodings in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2022.12.7)
# WARNING: Error parsing requirements for google-pasta: [Errno 2] No such file or directory: '/Users/abdulbhutta/opt/anaconda3/lib/python3.9/site-packages/google_pasta-0.2.0.dist-info/METADATA'

# %%
data = yf.download('AAPL','2008-01-01','2023-03-15')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head(5)
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2008-01-02  7.116786  7.152143  6.876786  6.958571   5.922568  1079178800
# 2008-01-03  6.978929  7.049643  6.881786  6.961786   5.925304   842066400
# 2008-01-04  6.837500  6.892857  6.388929  6.430357   5.472994  1455832000
# 2008-01-07  6.473214  6.557143  6.079643  6.344286   5.399738  2072193200
# 2008-01-08  6.433571  6.516429  6.100000  6.116071   5.205501  1523816000

# %%
data.tail(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-03-08  152.809998  153.470001  151.830002  152.869995  152.869995
# 2023-03-09  153.559998  154.539993  150.229996  150.589996  150.589996
# 2023-03-10  150.210007  150.940002  147.610001  148.500000  148.500000
# 2023-03-13  147.809998  153.139999  147.699997  150.470001  150.470001
# 2023-03-14  151.279999  153.399994  150.100006  152.589996  152.589996
#
#               Volume
# Date
# 2023-03-08  47204800
# 2023-03-09  53833600
# 2023-03-10  68524400
# 2023-03-13  84457100
# 2023-03-14  73695900

# %%
#Check for missing values
data.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Plotting the closing price history 
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(data['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
#Plot the moving average of the stock to select the best timestep for the LSTM model
#Select the moving average that shows the least volatility to select the best timestep
moving_average_day = [10,30,60, 90, 120, 180]

for ma in moving_average_day:
    column_name = "MA for %s days" %(str(ma))
    data[column_name] = data['Close'].rolling(ma).mean()

#Plot the moving average of the stock
plt.figure(figsize=(16,8))
plt.plot(data['Close'], label='Close Price History')
for ma in moving_average_day:
    column_name = "MA for %s days" %(str(ma))
    plt.plot(data[column_name], label=column_name)
plt.legend(loc='upper left')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Moving Average', fontsize=18)
plt.show()

# %%
#Plot the volume of the stock
plt.figure(figsize=(16,8))
plt.plot(data['Volume'], label='Volume History')
plt.legend(loc='upper left')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Daily Stock Volume', fontsize=18)
plt.show()

# %%
#plot the daily return of the stock
data['Daily Return'] = data['Close'].pct_change()
plt.figure(figsize=(16,8))
plt.plot(data['Daily Return'], label='Daily Return')
plt.legend(loc='upper left')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Daily Return ($)', fontsize=18)
plt.show()

# %%
#Determine if the stock is risky or not
plt.figure(figsize=(16,8))
plt.hist(data['Daily Return'].dropna(), bins=50)
plt.xlabel('Daily Return (%)', fontsize=18)
plt.ylabel('Total Count', fontsize=18)
plt.grid()
plt.show()
